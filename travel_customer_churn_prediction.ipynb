# %% [markdown]
# <a href="https://colab.research.google.com/github/KelvinLam05/travel_customer_churn_prediction/blob/main/travel_customer_churn_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Goal of the project**
#
# The aim of this project will be to predict whether a travel consumer will churn or not.

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# **Load the data**

# %%
# Load dataset
df = pd.read_csv('/content/customer_churn.csv')

# %%
# Rename Pandas columns to lower case
df.columns = df.columns.str.lower()

# %%
# Examine the data
df.head()
# Out:
#    age frequentflyer annualincomeclass  servicesopted  \
# 0   34            No     Middle Income              6
# 1   34           Yes        Low Income              5
# 2   37            No     Middle Income              3
# 3   30            No     Middle Income              2
# 4   30            No        Low Income              1
#
#   accountsyncedtosocialmedia bookedhotelornot  target
# 0                         No              Yes       0
# 1                        Yes               No       1
# 2                        Yes               No       0
# 3                         No               No       0
# 4                         No               No       0

# %%
# Overview of all variables, their datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         954 non-null    int64
#  1   frequentflyer               954 non-null    object
#  2   annualincomeclass           954 non-null    object
#  3   servicesopted               954 non-null    int64
#  4   accountsyncedtosocialmedia  954 non-null    object
#  5   bookedhotelornot            954 non-null    object
#  6   target                      954 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 52.3+ KB

# %% [markdown]
# **Examine the data**

# %% [markdown]
# If we run the Pandas value_counts( ) function we will see that this is an imbalanced dataset.

# %%
df['target'].value_counts()
# Out:
# 0    730
# 1    224
# Name: target, dtype: int64

# %% [markdown]
# **Check for missing values**

# %%
# Check for missing values
df.isnull().sum()
# Out:
# age                           0
# frequentflyer                 0
# annualincomeclass             0
# servicesopted                 0
# accountsyncedtosocialmedia    0
# bookedhotelornot              0
# target                        0
# dtype: int64

# %% [markdown]
# We don’t have any missing values. We are good to go.

# %% [markdown]
# **Examine categorical data cardinality**

# %% [markdown]
# Next we will take a look at the “cardinality” of the categorical variables. Cardinality is just a technical way of saying the number of unique values held within.

# %%
df.select_dtypes(include = ['object']).agg(['count', 'nunique']).T
# Out:
#                             count  nunique
# frequentflyer                 954        3
# annualincomeclass             954        3
# accountsyncedtosocialmedia    954        2
# bookedhotelornot              954        2

# %% [markdown]
# All of these features are quite low in cardinality.

# %% [markdown]
# **Split the train and test data**

# %%
X = df.drop('target', axis = 1)

# %%
y = df['target']

# %% [markdown]
# To divide X and y into the train and test datasets we need to train the model we will use the train_test_split( ) function from scikit-learn. We will assign 30% of the data to the test groups using the argument test_size = 0.3, and we will use the stratify = y option to ensure the target variable is present in the test and train data in equal proportions. The random_state = 42 argument means we get reproducible results each time we run the code, rather than a random mix, which may give us different results.

# %%
from sklearn.model_selection import train_test_split

# %%
# Isolate X and y variables, and perform train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)

# %% [markdown]
# **Create a model pipeline**

# %% [markdown]
# Next, we will create a model pipeline. This will handle the encoding of our data using the ColumnTransformer( ) feature. This also scales the data before we pass it to the model.
#
# I have also added some basic feature selection via SelectKBest( ), and have used the SMOTEENN to better handle class imbalance. I fiddled around with the SelectKBest parameters until I found the optimum number of features to leave in. This was around eight features. Doing this greatly improved performance.

# %%
import time
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline as imbpipeline
from sklearn.model_selection import cross_val_score

from sklearn.preprocessing import OneHotEncoder
from imblearn.combine import SMOTEENN
from sklearn.preprocessing import RobustScaler
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif
from sklearn.metrics import roc_auc_score

# %%
def get_pipeline(X, model):

    categorical_columns = list(X.select_dtypes(include = ['object']).columns.values.tolist())
    categorical_transformer = OneHotEncoder(drop = 'if_binary', sparse = False, handle_unknown = 'ignore')
    
    numeric_columns = list(X.select_dtypes(exclude = ['object']).columns.values.tolist())
    
    preprocessor = ColumnTransformer(transformers = [('numeric', 'passthrough', numeric_columns), ('categorical', categorical_transformer, categorical_columns)])

    bundled_pipeline = imbpipeline(steps = [('preprocessor', preprocessor),
                                            ('smote', SMOTEENN(random_state = 42)),
                                            ('scaler', RobustScaler()), 
                                            ('feature_selection', SelectKBest(score_func = mutual_info_classif, k = 8)),
                                            ('model', model)])

    return bundled_pipeline

# %% [markdown]
# **Select the best model**

# %% [markdown]
# Rather than simply selecting a single model, or repeating our code manually on a range of models, we can create another function to automatically test a wide range of possible models to determine the best one for our needs. To do this we first create a dictionary containing some a selection of base classifiers, including XGBoost, Random Forest, Decision Tree, SVC, and a Bernoulli Naive Bayes among others.
#
# We will create a Pandas dataframe into which we will store the data. Then we will loop over each of the models, fit it using the X_train and y_train data, then generate predictions from X_test and calculate the mean ROC/AUC score from 10 rounds of cross-validation. That will give us the ROC/AUC score for the X_test data, plus the average ROC/AUC score for the training data set.

# %%
from sklearn.dummy import DummyClassifier
from sklearn.neighbors import KNeighborsClassifier
from catboost import CatBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier, HistGradientBoostingClassifier
from xgboost import XGBClassifier, XGBRFClassifier
from sklearn.svm import LinearSVC, SVC
from sklearn.naive_bayes import BernoulliNB

# %%
def select_model(X, y, pipeline = None):

  classifiers = {}
  classifiers.update({'DummyClassifier': DummyClassifier(strategy = 'most_frequent', random_state = 42)})
  classifiers.update({'XGBClassifier': XGBClassifier(random_state = 42)})
  classifiers.update({'XGBRFClassifier': XGBRFClassifier(random_state = 42)})
  classifiers.update({'LogisticRegression': LogisticRegression(random_state = 42)})
  classifiers.update({'LGBMClassifier': LGBMClassifier(random_state = 42)})
  classifiers.update({'RandomForestClassifier': RandomForestClassifier(random_state = 42)})
  classifiers.update({'DecisionTreeClassifier': DecisionTreeClassifier(random_state = 42)})
  classifiers.update({'ExtraTreeClassifier': ExtraTreesClassifier(random_state = 42)})
  classifiers.update({'GradientBoostingClassifier': GradientBoostingClassifier(random_state = 42)})    
  classifiers.update({'BaggingClassifier': BaggingClassifier(random_state = 42)})
  classifiers.update({'AdaBoostClassifier': AdaBoostClassifier(random_state = 42)})
  classifiers.update({'HistGradientBoostingClassifier': HistGradientBoostingClassifier(random_state = 42)})
  classifiers.update({'KNeighborsClassifier': KNeighborsClassifier()})
  classifiers.update({'SGDClassifier': SGDClassifier(random_state = 42)})
  classifiers.update({'BaggingClassifier': BaggingClassifier(random_state = 42)})
  classifiers.update({'BernoulliNB': BernoulliNB()})
  classifiers.update({'LinearSVC': LinearSVC(random_state = 42)})
  classifiers.update({'SVC': SVC(random_state = 42)})
  classifiers.update({'CatBoostClassifier': CatBoostClassifier(silent = True, random_state = 42)})

  df_models = pd.DataFrame(columns = ['model', 'run_time', 'roc_auc_cv', 'roc_auc'])

  for key in classifiers:

      print('*', key)

      start_time = time.time()
      
      pipeline = get_pipeline(X_train, classifiers[key])
      pipeline.fit(X_train, y_train)
      y_pred = pipeline.predict(X_test)

      cv = cross_val_score(pipeline, X, y, cv = 10, scoring = 'roc_auc')

      row = {'model': key,
             'run_time': format(round((time.time() - start_time) / 60, 2)),
             'roc_auc_cv': cv.mean(),
             'roc_auc': roc_auc_score(y_test, y_pred)}

      df_models = df_models.append(row, ignore_index = True)

  df_models = df_models.sort_values(by = 'roc_auc_cv', ascending = False)
      
  return df_models

# %%
models = select_model(X_train, y_train)
# Out:
# * DummyClassifier
# * XGBClassifier
# * XGBRFClassifier
# * LogisticRegression
# * LGBMClassifier
# * RandomForestClassifier
# * DecisionTreeClassifier
# * ExtraTreeClassifier
# * GradientBoostingClassifier
# * BaggingClassifier
# * AdaBoostClassifier
# * HistGradientBoostingClassifier
# * KNeighborsClassifier
# * SGDClassifier
# * BernoulliNB
# * LinearSVC
# * SVC
# * CatBoostClassifier

# %% [markdown]
# Examining the output from the model selection step shows that we achieved very good results. The XGBClassifier performed particularly well.

# %%
models.head(10)
# Out:
#                              model run_time  roc_auc_cv   roc_auc
# 11  HistGradientBoostingClassifier     0.06    0.924024  0.827001
# 17              CatBoostClassifier      0.2    0.923317  0.891588
# 4                   LGBMClassifier     0.02    0.921789  0.819539
# 1                    XGBClassifier     0.02    0.920196  0.902951
# 8       GradientBoostingClassifier     0.03    0.908440  0.890299
# 5           RandomForestClassifier     0.04    0.901021  0.872117
# 7              ExtraTreeClassifier     0.04    0.890131  0.854919
# 10              AdaBoostClassifier     0.03    0.889837  0.839009
# 12            KNeighborsClassifier     0.01    0.881458  0.845183
# 9                BaggingClassifier     0.02    0.874142  0.884125

# %% [markdown]
# **Assessing performance**

# %% [markdown]
# When it comes to assessing models, there’s more to it than simply picking the one with the best score. It’s where the model that goes wrong that often matters. Too many false positives will waste the time of the sales team, while too many false negatives will mean the model isn’t predicting customer churn.

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
classifiers = {'XGBClassifier': XGBClassifier(random_state = 42), 
               'CatBoostClassifier': CatBoostClassifier(random_state = 42),
               'GradientBoostingClassifier': GradientBoostingClassifier(random_state = 42)}

df_models = pd.DataFrame(columns = ['model', 'roc_auc', 'precision', 'recall'])

for key in classifiers:

    print('*', key)
      
    pipeline = get_pipeline(X_train, classifiers[key])
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)

    roc_auc = roc_auc_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)

    row = {'model': key,
           'roc_auc': round(roc_auc, 3),
           'precision': round(precision, 3),
           'recall': round(recall, 3)}

    df_models = df_models.append(row, ignore_index = True)
# Out:
# * XGBClassifier
# * CatBoostClassifier
# Learning rate set to 0.009426
# 0:	learn: 0.6798751	total: 1.13ms	remaining: 1.13s
# 1:	learn: 0.6674599	total: 3.71ms	remaining: 1.85s
# 2:	learn: 0.6548966	total: 5.72ms	remaining: 1.9s
# 3:	learn: 0.6464276	total: 6.68ms	remaining: 1.66s
# 4:	learn: 0.6359319	total: 8.02ms	remaining: 1.6s
# 5:	learn: 0.6249612	total: 9.38ms	remaining: 1.55s
# 6:	learn: 0.6158073	total: 10.6ms	remaining: 1.51s
# 7:	learn: 0.6058225	total: 12.1ms	remaining: 1.5s
# 8:	learn: 0.5957319	total: 13.7ms	remaining: 1.5s
# 9:	learn: 0.5852409	total: 15.1ms	remaining: 1.5s
# 10:	learn: 0.5761923	total: 16.4ms	remaining: 1.48s
# 11:	learn: 0.5674579	total: 17.8ms	remaining: 1.47s
# 12:	learn: 0.5591005	total: 19.3ms	remaining: 1.46s
# 13:	learn: 0.5497785	total: 20.6ms	remaining: 1.45s
# 14:	learn: 0.5421214	total: 21.9ms	remaining: 1.44s
# 15:	learn: 0.5346505	total: 23.2ms	remaining: 1.43s
# 16:	learn: 0.5252514	total: 24.7ms	remaining: 1.43s
# 17:	learn: 0.5177529	total: 25.9ms	remaining: 1.41s
# 18:	learn: 0.5093397	total: 27.5ms	remaining: 1.42s
# 19:	learn: 0.5013719	total: 28.8ms	remaining: 1.41s
# 20:	learn: 0.4922090	total: 30.2ms	remaining: 1.41s
# 21:	learn: 0.4868217	total: 31.4ms	remaining: 1.39s
# 22:	learn: 0.4784163	total: 32.7ms	remaining: 1.39s
# 23:	learn: 0.4713455	total: 34ms	remaining: 1.38s
# 24:	learn: 0.4663401	total: 35.4ms	remaining: 1.38s
# 25:	learn: 0.4597550	total: 36.6ms	remaining: 1.37s
# 26:	learn: 0.4527645	total: 37.9ms	remaining: 1.37s
# 27:	learn: 0.4457501	total: 39.2ms	remaining: 1.36s
# 28:	learn: 0.4402725	total: 40.5ms	remaining: 1.36s
# 29:	learn: 0.4326382	total: 41.8ms	remaining: 1.35s
# 30:	learn: 0.4270869	total: 43.1ms	remaining: 1.35s
# 31:	learn: 0.4225711	total: 44.4ms	remaining: 1.34s
# 32:	learn: 0.4157668	total: 45.7ms	remaining: 1.34s
# 33:	learn: 0.4098495	total: 47ms	remaining: 1.33s
# 34:	learn: 0.4057458	total: 48.3ms	remaining: 1.33s
# 35:	learn: 0.4001884	total: 50.4ms	remaining: 1.35s
# 36:	learn: 0.3940871	total: 51.9ms	remaining: 1.35s
# 37:	learn: 0.3896856	total: 53.7ms	remaining: 1.36s
# 38:	learn: 0.3845546	total: 55.1ms	remaining: 1.36s
# 39:	learn: 0.3793460	total: 56.4ms	remaining: 1.35s
# 40:	learn: 0.3736313	total: 57.6ms	remaining: 1.35s
# 41:	learn: 0.3700144	total: 58.9ms	remaining: 1.34s
# 42:	learn: 0.3646031	total: 60.2ms	remaining: 1.34s
# 43:	learn: 0.3600901	total: 61.5ms	remaining: 1.34s
# 44:	learn: 0.3552277	total: 63.1ms	remaining: 1.34s
# 45:	learn: 0.3503135	total: 64.4ms	remaining: 1.33s
# 46:	learn: 0.3454605	total: 65.8ms	remaining: 1.33s
# 47:	learn: 0.3410674	total: 67.1ms	remaining: 1.33s
# 48:	learn: 0.3364861	total: 68.5ms	remaining: 1.33s
# 49:	learn: 0.3321471	total: 69.8ms	remaining: 1.32s
# 50:	learn: 0.3276224	total: 71.1ms	remaining: 1.32s
# 51:	learn: 0.3250271	total: 73.2ms	remaining: 1.33s
# 52:	learn: 0.3219915	total: 74.4ms	remaining: 1.33s
# 53:	learn: 0.3186792	total: 75.7ms	remaining: 1.33s
# 54:	learn: 0.3155172	total: 77ms	remaining: 1.32s
# 55:	learn: 0.3120751	total: 78.4ms	remaining: 1.32s
# 56:	learn: 0.3093936	total: 79.7ms	remaining: 1.32s
# 57:	learn: 0.3059082	total: 81.1ms	remaining: 1.32s
# 58:	learn: 0.3022202	total: 82.4ms	remaining: 1.31s
# 59:	learn: 0.2990206	total: 84ms	remaining: 1.32s
# 60:	learn: 0.2965329	total: 85.4ms	remaining: 1.31s
# 61:	learn: 0.2926677	total: 86.7ms	remaining: 1.31s
# 62:	learn: 0.2890606	total: 87.9ms	remaining: 1.31s
# 63:	learn: 0.2851705	total: 89.2ms	remaining: 1.3s
# 64:	learn: 0.2817027	total: 90.6ms	remaining: 1.3s
# 65:	learn: 0.2789897	total: 91.8ms	remaining: 1.3s
# 66:	learn: 0.2762293	total: 93.1ms	remaining: 1.3s
# 67:	learn: 0.2738771	total: 94.4ms	remaining: 1.29s
# 68:	learn: 0.2710436	total: 95.6ms	remaining: 1.29s
# 69:	learn: 0.2680309	total: 96.9ms	remaining: 1.29s
# 70:	learn: 0.2651720	total: 98.1ms	remaining: 1.28s
# 71:	learn: 0.2618354	total: 99.8ms	remaining: 1.29s
# 72:	learn: 0.2595586	total: 101ms	remaining: 1.28s
# 73:	learn: 0.2565454	total: 102ms	remaining: 1.28s
# 74:	learn: 0.2542607	total: 104ms	remaining: 1.28s
# 75:	learn: 0.2523301	total: 105ms	remaining: 1.28s
# 76:	learn: 0.2497515	total: 106ms	remaining: 1.27s
# 77:	learn: 0.2481203	total: 108ms	remaining: 1.27s
# 78:	learn: 0.2463310	total: 109ms	remaining: 1.27s
# 79:	learn: 0.2439309	total: 110ms	remaining: 1.27s
# 80:	learn: 0.2408824	total: 112ms	remaining: 1.26s
# 81:	learn: 0.2384508	total: 113ms	remaining: 1.26s
# 82:	learn: 0.2365929	total: 114ms	remaining: 1.26s
# 83:	learn: 0.2346149	total: 115ms	remaining: 1.26s
# 84:	learn: 0.2327220	total: 117ms	remaining: 1.26s
# 85:	learn: 0.2294294	total: 118ms	remaining: 1.25s
# 86:	learn: 0.2269064	total: 119ms	remaining: 1.25s
# 87:	learn: 0.2245566	total: 121ms	remaining: 1.25s
# 88:	learn: 0.2226559	total: 122ms	remaining: 1.25s
# 89:	learn: 0.2205136	total: 123ms	remaining: 1.25s
# 90:	learn: 0.2184713	total: 125ms	remaining: 1.25s
# 91:	learn: 0.2165339	total: 126ms	remaining: 1.24s
# 92:	learn: 0.2148326	total: 127ms	remaining: 1.24s
# 93:	learn: 0.2131616	total: 129ms	remaining: 1.24s
# 94:	learn: 0.2107739	total: 130ms	remaining: 1.24s
# 95:	learn: 0.2082118	total: 131ms	remaining: 1.24s
# 96:	learn: 0.2060441	total: 133ms	remaining: 1.24s
# 97:	learn: 0.2043169	total: 134ms	remaining: 1.23s
# 98:	learn: 0.2025805	total: 135ms	remaining: 1.23s
# 99:	learn: 0.2007722	total: 137ms	remaining: 1.23s
# 100:	learn: 0.1994324	total: 138ms	remaining: 1.23s
# 101:	learn: 0.1974818	total: 139ms	remaining: 1.23s
# 102:	learn: 0.1959122	total: 141ms	remaining: 1.22s
# 103:	learn: 0.1951415	total: 142ms	remaining: 1.22s
# 104:	learn: 0.1931861	total: 143ms	remaining: 1.22s
# 105:	learn: 0.1915363	total: 144ms	remaining: 1.22s
# 106:	learn: 0.1900017	total: 146ms	remaining: 1.22s
# 107:	learn: 0.1885273	total: 151ms	remaining: 1.24s
# 108:	learn: 0.1875379	total: 153ms	remaining: 1.25s
# 109:	learn: 0.1855767	total: 157ms	remaining: 1.27s
# 110:	learn: 0.1844620	total: 159ms	remaining: 1.27s
# 111:	learn: 0.1836424	total: 160ms	remaining: 1.26s
# 112:	learn: 0.1820961	total: 161ms	remaining: 1.26s
# 113:	learn: 0.1813575	total: 162ms	remaining: 1.26s
# 114:	learn: 0.1798894	total: 163ms	remaining: 1.26s
# 115:	learn: 0.1786371	total: 165ms	remaining: 1.25s
# 116:	learn: 0.1770347	total: 166ms	remaining: 1.25s
# 117:	learn: 0.1756154	total: 167ms	remaining: 1.25s
# 118:	learn: 0.1741189	total: 169ms	remaining: 1.25s
# 119:	learn: 0.1727910	total: 170ms	remaining: 1.25s
# 120:	learn: 0.1717312	total: 172ms	remaining: 1.25s
# 121:	learn: 0.1698734	total: 173ms	remaining: 1.24s
# 122:	learn: 0.1688208	total: 174ms	remaining: 1.24s
# 123:	learn: 0.1672771	total: 176ms	remaining: 1.24s
# 124:	learn: 0.1660370	total: 177ms	remaining: 1.24s
# 125:	learn: 0.1649394	total: 178ms	remaining: 1.24s
# 126:	learn: 0.1637919	total: 186ms	remaining: 1.27s
# 127:	learn: 0.1626794	total: 187ms	remaining: 1.27s
# 128:	learn: 0.1607400	total: 188ms	remaining: 1.27s
# 129:	learn: 0.1596872	total: 190ms	remaining: 1.27s
# 130:	learn: 0.1586043	total: 191ms	remaining: 1.27s
# 131:	learn: 0.1575376	total: 192ms	remaining: 1.26s
# 132:	learn: 0.1562983	total: 194ms	remaining: 1.26s
# 133:	learn: 0.1554390	total: 195ms	remaining: 1.26s
# 134:	learn: 0.1545362	total: 196ms	remaining: 1.26s
# 135:	learn: 0.1532525	total: 198ms	remaining: 1.26s
# 136:	learn: 0.1520185	total: 199ms	remaining: 1.26s
# 137:	learn: 0.1511183	total: 201ms	remaining: 1.25s
# 138:	learn: 0.1503669	total: 202ms	remaining: 1.25s
# 139:	learn: 0.1497013	total: 203ms	remaining: 1.25s
# 140:	learn: 0.1488627	total: 205ms	remaining: 1.25s
# 141:	learn: 0.1479572	total: 206ms	remaining: 1.25s
# 142:	learn: 0.1470753	total: 208ms	remaining: 1.25s
# 143:	learn: 0.1461723	total: 209ms	remaining: 1.24s
# 144:	learn: 0.1451663	total: 211ms	remaining: 1.24s
# 145:	learn: 0.1445745	total: 212ms	remaining: 1.24s
# 146:	learn: 0.1436911	total: 213ms	remaining: 1.24s
# 147:	learn: 0.1427447	total: 215ms	remaining: 1.23s
# 148:	learn: 0.1420017	total: 216ms	remaining: 1.23s
# 149:	learn: 0.1411262	total: 217ms	remaining: 1.23s
# 150:	learn: 0.1399681	total: 218ms	remaining: 1.23s
# 151:	learn: 0.1393998	total: 220ms	remaining: 1.23s
# 152:	learn: 0.1385494	total: 221ms	remaining: 1.22s
# 153:	learn: 0.1374452	total: 222ms	remaining: 1.22s
# 154:	learn: 0.1363032	total: 224ms	remaining: 1.22s
# 155:	learn: 0.1356107	total: 230ms	remaining: 1.24s
# 156:	learn: 0.1344212	total: 232ms	remaining: 1.25s
# 157:	learn: 0.1338438	total: 235ms	remaining: 1.25s
# 158:	learn: 0.1332912	total: 236ms	remaining: 1.25s
# 159:	learn: 0.1329435	total: 237ms	remaining: 1.25s
# 160:	learn: 0.1321440	total: 239ms	remaining: 1.24s
# 161:	learn: 0.1311108	total: 240ms	remaining: 1.24s
# 162:	learn: 0.1302586	total: 241ms	remaining: 1.24s
# 163:	learn: 0.1296540	total: 243ms	remaining: 1.24s
# 164:	learn: 0.1290411	total: 244ms	remaining: 1.23s
# 165:	learn: 0.1280473	total: 245ms	remaining: 1.23s
# 166:	learn: 0.1271229	total: 247ms	remaining: 1.23s
# 167:	learn: 0.1262016	total: 248ms	remaining: 1.23s
# 168:	learn: 0.1257568	total: 249ms	remaining: 1.23s
# 169:	learn: 0.1256347	total: 250ms	remaining: 1.22s
# 170:	learn: 0.1250218	total: 251ms	remaining: 1.22s
# 171:	learn: 0.1241971	total: 253ms	remaining: 1.22s
# 172:	learn: 0.1236508	total: 254ms	remaining: 1.21s
# 173:	learn: 0.1223360	total: 255ms	remaining: 1.21s
# 174:	learn: 0.1215435	total: 257ms	remaining: 1.21s
# 175:	learn: 0.1210746	total: 258ms	remaining: 1.21s
# 176:	learn: 0.1205823	total: 259ms	remaining: 1.21s
# 177:	learn: 0.1200273	total: 261ms	remaining: 1.2s
# 178:	learn: 0.1194289	total: 262ms	remaining: 1.2s
# 179:	learn: 0.1190711	total: 263ms	remaining: 1.2s
# 180:	learn: 0.1182367	total: 265ms	remaining: 1.2s
# 181:	learn: 0.1174313	total: 266ms	remaining: 1.2s
# 182:	learn: 0.1166230	total: 268ms	remaining: 1.2s
# 183:	learn: 0.1158667	total: 269ms	remaining: 1.2s
# 184:	learn: 0.1154291	total: 271ms	remaining: 1.19s
# 185:	learn: 0.1147633	total: 272ms	remaining: 1.19s
# 186:	learn: 0.1137354	total: 273ms	remaining: 1.19s
# 187:	learn: 0.1130106	total: 275ms	remaining: 1.19s
# 188:	learn: 0.1122404	total: 277ms	remaining: 1.19s
# 189:	learn: 0.1114048	total: 278ms	remaining: 1.19s
# 190:	learn: 0.1106399	total: 280ms	remaining: 1.18s
# 191:	learn: 0.1096873	total: 281ms	remaining: 1.18s
# 192:	learn: 0.1091850	total: 283ms	remaining: 1.18s
# 193:	learn: 0.1084384	total: 284ms	remaining: 1.18s
# 194:	learn: 0.1078763	total: 286ms	remaining: 1.18s
# 195:	learn: 0.1069699	total: 287ms	remaining: 1.18s
# 196:	learn: 0.1062140	total: 288ms	remaining: 1.18s
# 197:	learn: 0.1053893	total: 290ms	remaining: 1.17s
# 198:	learn: 0.1047157	total: 291ms	remaining: 1.17s
# 199:	learn: 0.1040839	total: 293ms	remaining: 1.17s
# 200:	learn: 0.1037846	total: 294ms	remaining: 1.17s
# 201:	learn: 0.1031889	total: 295ms	remaining: 1.17s
# 202:	learn: 0.1027165	total: 297ms	remaining: 1.17s
# 203:	learn: 0.1020248	total: 298ms	remaining: 1.16s
# 204:	learn: 0.1017173	total: 300ms	remaining: 1.16s
# 205:	learn: 0.1011107	total: 301ms	remaining: 1.16s
# 206:	learn: 0.1007692	total: 302ms	remaining: 1.16s
# 207:	learn: 0.1004122	total: 304ms	remaining: 1.16s
# 208:	learn: 0.1001281	total: 305ms	remaining: 1.15s
# 209:	learn: 0.0995276	total: 306ms	remaining: 1.15s
# 210:	learn: 0.0990165	total: 308ms	remaining: 1.15s
# 211:	learn: 0.0986123	total: 309ms	remaining: 1.15s
# 212:	learn: 0.0981029	total: 310ms	remaining: 1.15s
# 213:	learn: 0.0976924	total: 312ms	remaining: 1.14s
# 214:	learn: 0.0973812	total: 313ms	remaining: 1.14s
# 215:	learn: 0.0970025	total: 314ms	remaining: 1.14s
# 216:	learn: 0.0965984	total: 316ms	remaining: 1.14s
# 217:	learn: 0.0961792	total: 317ms	remaining: 1.14s
# 218:	learn: 0.0959022	total: 319ms	remaining: 1.14s
# 219:	learn: 0.0952886	total: 320ms	remaining: 1.13s
# 220:	learn: 0.0947355	total: 321ms	remaining: 1.13s
# 221:	learn: 0.0943290	total: 322ms	remaining: 1.13s
# 222:	learn: 0.0937565	total: 324ms	remaining: 1.13s
# 223:	learn: 0.0934914	total: 325ms	remaining: 1.13s
# 224:	learn: 0.0929591	total: 327ms	remaining: 1.12s
# 225:	learn: 0.0925293	total: 328ms	remaining: 1.12s
# 226:	learn: 0.0920691	total: 329ms	remaining: 1.12s
# 227:	learn: 0.0919184	total: 331ms	remaining: 1.12s
# 228:	learn: 0.0914020	total: 332ms	remaining: 1.12s
# 229:	learn: 0.0910358	total: 333ms	remaining: 1.11s
# 230:	learn: 0.0905339	total: 334ms	remaining: 1.11s
# 231:	learn: 0.0902902	total: 336ms	remaining: 1.11s
# 232:	learn: 0.0897835	total: 337ms	remaining: 1.11s
# 233:	learn: 0.0894836	total: 338ms	remaining: 1.11s
# 234:	learn: 0.0890313	total: 340ms	remaining: 1.1s
# 235:	learn: 0.0887509	total: 341ms	remaining: 1.1s
# 236:	learn: 0.0883709	total: 342ms	remaining: 1.1s
# 237:	learn: 0.0880964	total: 344ms	remaining: 1.1s
# 238:	learn: 0.0875319	total: 345ms	remaining: 1.1s
# 239:	learn: 0.0871295	total: 346ms	remaining: 1.1s
# 240:	learn: 0.0867762	total: 348ms	remaining: 1.09s
# 241:	learn: 0.0861561	total: 349ms	remaining: 1.09s
# 242:	learn: 0.0857393	total: 350ms	remaining: 1.09s
# 243:	learn: 0.0854216	total: 352ms	remaining: 1.09s
# 244:	learn: 0.0851198	total: 353ms	remaining: 1.09s
# 245:	learn: 0.0848431	total: 355ms	remaining: 1.09s
# 246:	learn: 0.0845250	total: 356ms	remaining: 1.08s
# 247:	learn: 0.0842798	total: 357ms	remaining: 1.08s
# 248:	learn: 0.0839763	total: 359ms	remaining: 1.08s
# 249:	learn: 0.0834517	total: 368ms	remaining: 1.1s
# 250:	learn: 0.0830536	total: 370ms	remaining: 1.1s
# 251:	learn: 0.0827288	total: 371ms	remaining: 1.1s
# 252:	learn: 0.0824708	total: 373ms	remaining: 1.1s
# 253:	learn: 0.0820800	total: 374ms	remaining: 1.1s
# 254:	learn: 0.0818784	total: 375ms	remaining: 1.1s
# 255:	learn: 0.0814625	total: 377ms	remaining: 1.09s
# 256:	learn: 0.0811062	total: 378ms	remaining: 1.09s
# 257:	learn: 0.0806053	total: 379ms	remaining: 1.09s
# 258:	learn: 0.0803463	total: 381ms	remaining: 1.09s
# 259:	learn: 0.0799893	total: 382ms	remaining: 1.09s
# 260:	learn: 0.0796269	total: 383ms	remaining: 1.08s
# 261:	learn: 0.0792657	total: 385ms	remaining: 1.08s
# 262:	learn: 0.0788129	total: 386ms	remaining: 1.08s
# 263:	learn: 0.0784435	total: 387ms	remaining: 1.08s
# 264:	learn: 0.0782315	total: 389ms	remaining: 1.08s
# 265:	learn: 0.0779124	total: 392ms	remaining: 1.08s
# 266:	learn: 0.0775978	total: 393ms	remaining: 1.08s
# 267:	learn: 0.0772200	total: 394ms	remaining: 1.08s
# 268:	learn: 0.0769937	total: 395ms	remaining: 1.07s
# 269:	learn: 0.0766609	total: 397ms	remaining: 1.07s
# 270:	learn: 0.0764028	total: 398ms	remaining: 1.07s
# 271:	learn: 0.0761974	total: 400ms	remaining: 1.07s
# 272:	learn: 0.0758430	total: 401ms	remaining: 1.07s
# 273:	learn: 0.0755732	total: 403ms	remaining: 1.07s
# 274:	learn: 0.0754146	total: 404ms	remaining: 1.06s
# 275:	learn: 0.0750777	total: 406ms	remaining: 1.06s
# 276:	learn: 0.0747671	total: 407ms	remaining: 1.06s
# 277:	learn: 0.0743884	total: 408ms	remaining: 1.06s
# 278:	learn: 0.0740019	total: 410ms	remaining: 1.06s
# 279:	learn: 0.0738670	total: 411ms	remaining: 1.06s
# 280:	learn: 0.0734603	total: 412ms	remaining: 1.05s
# 281:	learn: 0.0731680	total: 414ms	remaining: 1.05s
# 282:	learn: 0.0729393	total: 415ms	remaining: 1.05s
# 283:	learn: 0.0726986	total: 416ms	remaining: 1.05s
# 284:	learn: 0.0725113	total: 418ms	remaining: 1.05s
# 285:	learn: 0.0722299	total: 419ms	remaining: 1.04s
# 286:	learn: 0.0719781	total: 420ms	remaining: 1.04s
# 287:	learn: 0.0716555	total: 421ms	remaining: 1.04s
# 288:	learn: 0.0714316	total: 423ms	remaining: 1.04s
# 289:	learn: 0.0712777	total: 424ms	remaining: 1.04s
# 290:	learn: 0.0708536	total: 425ms	remaining: 1.04s
# 291:	learn: 0.0707904	total: 427ms	remaining: 1.03s
# 292:	learn: 0.0704528	total: 430ms	remaining: 1.04s
# 293:	learn: 0.0701891	total: 432ms	remaining: 1.04s
# 294:	learn: 0.0699368	total: 434ms	remaining: 1.04s
# 295:	learn: 0.0696804	total: 437ms	remaining: 1.04s
# 296:	learn: 0.0694012	total: 440ms	remaining: 1.04s
# 297:	learn: 0.0690418	total: 443ms	remaining: 1.04s
# 298:	learn: 0.0686193	total: 445ms	remaining: 1.04s
# 299:	learn: 0.0684315	total: 446ms	remaining: 1.04s
# 300:	learn: 0.0681049	total: 447ms	remaining: 1.04s
# 301:	learn: 0.0679549	total: 448ms	remaining: 1.03s
# 302:	learn: 0.0676426	total: 450ms	remaining: 1.03s
# 303:	learn: 0.0672989	total: 451ms	remaining: 1.03s
# 304:	learn: 0.0670938	total: 452ms	remaining: 1.03s
# 305:	learn: 0.0669211	total: 453ms	remaining: 1.03s
# 306:	learn: 0.0667085	total: 455ms	remaining: 1.03s
# 307:	learn: 0.0664072	total: 456ms	remaining: 1.02s
# 308:	learn: 0.0661220	total: 457ms	remaining: 1.02s
# 309:	learn: 0.0659424	total: 459ms	remaining: 1.02s
# 310:	learn: 0.0656506	total: 460ms	remaining: 1.02s
# 311:	learn: 0.0654169	total: 461ms	remaining: 1.02s
# 312:	learn: 0.0652170	total: 463ms	remaining: 1.02s
# 313:	learn: 0.0649531	total: 464ms	remaining: 1.01s
# 314:	learn: 0.0647336	total: 466ms	remaining: 1.01s
# 315:	learn: 0.0643661	total: 467ms	remaining: 1.01s
# 316:	learn: 0.0641029	total: 469ms	remaining: 1.01s
# 317:	learn: 0.0637985	total: 470ms	remaining: 1.01s
# 318:	learn: 0.0637186	total: 472ms	remaining: 1.01s
# 319:	learn: 0.0635995	total: 473ms	remaining: 1s
# 320:	learn: 0.0633343	total: 474ms	remaining: 1s
# 321:	learn: 0.0629750	total: 476ms	remaining: 1s
# 322:	learn: 0.0628070	total: 477ms	remaining: 1000ms
# 323:	learn: 0.0624957	total: 478ms	remaining: 998ms
# 324:	learn: 0.0623987	total: 480ms	remaining: 996ms
# 325:	learn: 0.0622218	total: 481ms	remaining: 994ms
# 326:	learn: 0.0619997	total: 482ms	remaining: 993ms
# 327:	learn: 0.0616982	total: 484ms	remaining: 991ms
# 328:	learn: 0.0614031	total: 485ms	remaining: 989ms
# 329:	learn: 0.0610919	total: 486ms	remaining: 987ms
# 330:	learn: 0.0607616	total: 487ms	remaining: 985ms
# 331:	learn: 0.0604736	total: 489ms	remaining: 983ms
# 332:	learn: 0.0602310	total: 490ms	remaining: 982ms
# 333:	learn: 0.0601257	total: 491ms	remaining: 980ms
# 334:	learn: 0.0598345	total: 493ms	remaining: 978ms
# 335:	learn: 0.0596432	total: 494ms	remaining: 977ms
# 336:	learn: 0.0595311	total: 495ms	remaining: 975ms
# 337:	learn: 0.0594107	total: 497ms	remaining: 973ms
# 338:	learn: 0.0592630	total: 498ms	remaining: 971ms
# 339:	learn: 0.0589965	total: 499ms	remaining: 969ms
# 340:	learn: 0.0587835	total: 501ms	remaining: 967ms
# 341:	learn: 0.0586353	total: 502ms	remaining: 966ms
# 342:	learn: 0.0585301	total: 504ms	remaining: 965ms
# 343:	learn: 0.0583253	total: 505ms	remaining: 963ms
# 344:	learn: 0.0581489	total: 506ms	remaining: 961ms
# 345:	learn: 0.0579402	total: 508ms	remaining: 960ms
# 346:	learn: 0.0577072	total: 511ms	remaining: 961ms
# 347:	learn: 0.0575313	total: 514ms	remaining: 962ms
# 348:	learn: 0.0574406	total: 515ms	remaining: 961ms
# 349:	learn: 0.0573029	total: 522ms	remaining: 970ms
# 350:	learn: 0.0569992	total: 524ms	remaining: 969ms
# 351:	learn: 0.0567992	total: 525ms	remaining: 967ms
# 352:	learn: 0.0565231	total: 527ms	remaining: 967ms
# 353:	learn: 0.0563026	total: 529ms	remaining: 965ms
# 354:	learn: 0.0560561	total: 530ms	remaining: 964ms
# 355:	learn: 0.0557865	total: 532ms	remaining: 962ms
# 356:	learn: 0.0554670	total: 533ms	remaining: 960ms
# 357:	learn: 0.0552830	total: 534ms	remaining: 958ms
# 358:	learn: 0.0551747	total: 536ms	remaining: 957ms
# 359:	learn: 0.0549271	total: 537ms	remaining: 955ms
# 360:	learn: 0.0548419	total: 538ms	remaining: 953ms
# 361:	learn: 0.0547260	total: 540ms	remaining: 951ms
# 362:	learn: 0.0544853	total: 541ms	remaining: 950ms
# 363:	learn: 0.0542451	total: 542ms	remaining: 948ms
# 364:	learn: 0.0539473	total: 544ms	remaining: 946ms
# 365:	learn: 0.0537540	total: 545ms	remaining: 944ms
# 366:	learn: 0.0536027	total: 548ms	remaining: 946ms
# 367:	learn: 0.0534911	total: 550ms	remaining: 944ms
# 368:	learn: 0.0532200	total: 551ms	remaining: 942ms
# 369:	learn: 0.0529746	total: 552ms	remaining: 941ms
# 370:	learn: 0.0527504	total: 554ms	remaining: 939ms
# 371:	learn: 0.0524993	total: 555ms	remaining: 937ms
# 372:	learn: 0.0523588	total: 556ms	remaining: 935ms
# 373:	learn: 0.0522309	total: 558ms	remaining: 933ms
# 374:	learn: 0.0521365	total: 559ms	remaining: 931ms
# 375:	learn: 0.0520455	total: 560ms	remaining: 930ms
# 376:	learn: 0.0519395	total: 562ms	remaining: 928ms
# 377:	learn: 0.0517878	total: 563ms	remaining: 926ms
# 378:	learn: 0.0516160	total: 564ms	remaining: 925ms
# 379:	learn: 0.0513876	total: 566ms	remaining: 923ms
# 380:	learn: 0.0511852	total: 567ms	remaining: 921ms
# 381:	learn: 0.0510845	total: 568ms	remaining: 919ms
# 382:	learn: 0.0509658	total: 570ms	remaining: 918ms
# 383:	learn: 0.0507471	total: 571ms	remaining: 917ms
# 384:	learn: 0.0505912	total: 573ms	remaining: 915ms
# 385:	learn: 0.0503678	total: 574ms	remaining: 913ms
# 386:	learn: 0.0502682	total: 575ms	remaining: 911ms
# 387:	learn: 0.0501709	total: 577ms	remaining: 910ms
# 388:	learn: 0.0500333	total: 578ms	remaining: 908ms
# 389:	learn: 0.0499536	total: 580ms	remaining: 906ms
# 390:	learn: 0.0498279	total: 581ms	remaining: 905ms
# 391:	learn: 0.0496572	total: 582ms	remaining: 903ms
# 392:	learn: 0.0494638	total: 583ms	remaining: 901ms
# 393:	learn: 0.0493011	total: 585ms	remaining: 899ms
# 394:	learn: 0.0490842	total: 586ms	remaining: 898ms
# 395:	learn: 0.0489073	total: 587ms	remaining: 896ms
# 396:	learn: 0.0487325	total: 589ms	remaining: 894ms
# 397:	learn: 0.0484901	total: 590ms	remaining: 892ms
# 398:	learn: 0.0482450	total: 591ms	remaining: 890ms
# 399:	learn: 0.0480485	total: 592ms	remaining: 889ms
# 400:	learn: 0.0478615	total: 594ms	remaining: 887ms
# 401:	learn: 0.0476064	total: 595ms	remaining: 885ms
# 402:	learn: 0.0474228	total: 596ms	remaining: 884ms
# 403:	learn: 0.0472633	total: 598ms	remaining: 882ms
# 404:	learn: 0.0470564	total: 599ms	remaining: 880ms
# 405:	learn: 0.0468998	total: 600ms	remaining: 878ms
# 406:	learn: 0.0467825	total: 602ms	remaining: 877ms
# 407:	learn: 0.0466691	total: 603ms	remaining: 875ms
# 408:	learn: 0.0465433	total: 604ms	remaining: 873ms
# 409:	learn: 0.0464105	total: 606ms	remaining: 872ms
# 410:	learn: 0.0463377	total: 607ms	remaining: 870ms
# 411:	learn: 0.0461113	total: 608ms	remaining: 868ms
# 412:	learn: 0.0459978	total: 610ms	remaining: 866ms
# 413:	learn: 0.0458527	total: 611ms	remaining: 865ms
# 414:	learn: 0.0457228	total: 612ms	remaining: 863ms
# 415:	learn: 0.0456083	total: 613ms	remaining: 861ms
# 416:	learn: 0.0455385	total: 615ms	remaining: 859ms
# 417:	learn: 0.0453871	total: 616ms	remaining: 858ms
# 418:	learn: 0.0452450	total: 617ms	remaining: 856ms
# 419:	learn: 0.0450930	total: 619ms	remaining: 854ms
# 420:	learn: 0.0449337	total: 620ms	remaining: 853ms
# 421:	learn: 0.0447616	total: 621ms	remaining: 851ms
# 422:	learn: 0.0446825	total: 623ms	remaining: 849ms
# 423:	learn: 0.0444672	total: 624ms	remaining: 847ms
# 424:	learn: 0.0443033	total: 625ms	remaining: 846ms
# 425:	learn: 0.0441768	total: 626ms	remaining: 844ms
# 426:	learn: 0.0440002	total: 628ms	remaining: 842ms
# 427:	learn: 0.0438878	total: 629ms	remaining: 841ms
# 428:	learn: 0.0438294	total: 630ms	remaining: 839ms
# 429:	learn: 0.0436696	total: 632ms	remaining: 837ms
# 430:	learn: 0.0435636	total: 633ms	remaining: 836ms
# 431:	learn: 0.0434588	total: 634ms	remaining: 834ms
# 432:	learn: 0.0432437	total: 636ms	remaining: 833ms
# 433:	learn: 0.0431138	total: 637ms	remaining: 831ms
# 434:	learn: 0.0429554	total: 639ms	remaining: 829ms
# 435:	learn: 0.0427718	total: 640ms	remaining: 828ms
# 436:	learn: 0.0426753	total: 641ms	remaining: 826ms
# 437:	learn: 0.0425669	total: 643ms	remaining: 824ms
# 438:	learn: 0.0424706	total: 644ms	remaining: 823ms
# 439:	learn: 0.0424173	total: 645ms	remaining: 821ms
# 440:	learn: 0.0422465	total: 647ms	remaining: 820ms
# 441:	learn: 0.0421180	total: 648ms	remaining: 818ms
# 442:	learn: 0.0420054	total: 649ms	remaining: 816ms
# 443:	learn: 0.0418945	total: 650ms	remaining: 814ms
# 444:	learn: 0.0416920	total: 652ms	remaining: 813ms
# 445:	learn: 0.0416512	total: 653ms	remaining: 811ms
# 446:	learn: 0.0415125	total: 654ms	remaining: 810ms
# 447:	learn: 0.0412914	total: 656ms	remaining: 808ms
# 448:	learn: 0.0411959	total: 657ms	remaining: 806ms
# 449:	learn: 0.0410085	total: 658ms	remaining: 805ms
# 450:	learn: 0.0409360	total: 660ms	remaining: 803ms
# 451:	learn: 0.0407615	total: 661ms	remaining: 801ms
# 452:	learn: 0.0406642	total: 662ms	remaining: 800ms
# 453:	learn: 0.0405915	total: 664ms	remaining: 798ms
# 454:	learn: 0.0404158	total: 665ms	remaining: 796ms
# 455:	learn: 0.0403080	total: 666ms	remaining: 795ms
# 456:	learn: 0.0402287	total: 667ms	remaining: 793ms
# 457:	learn: 0.0400851	total: 669ms	remaining: 791ms
# 458:	learn: 0.0400153	total: 670ms	remaining: 790ms
# 459:	learn: 0.0398713	total: 671ms	remaining: 788ms
# 460:	learn: 0.0396877	total: 673ms	remaining: 787ms
# 461:	learn: 0.0395213	total: 674ms	remaining: 785ms
# 462:	learn: 0.0393653	total: 676ms	remaining: 783ms
# 463:	learn: 0.0392089	total: 677ms	remaining: 782ms
# 464:	learn: 0.0391083	total: 678ms	remaining: 780ms
# 465:	learn: 0.0389715	total: 680ms	remaining: 779ms
# 466:	learn: 0.0388807	total: 681ms	remaining: 777ms
# 467:	learn: 0.0388244	total: 682ms	remaining: 776ms
# 468:	learn: 0.0387046	total: 684ms	remaining: 774ms
# 469:	learn: 0.0386105	total: 685ms	remaining: 772ms
# 470:	learn: 0.0385044	total: 686ms	remaining: 771ms
# 471:	learn: 0.0383091	total: 688ms	remaining: 769ms
# 472:	learn: 0.0382402	total: 689ms	remaining: 768ms
# 473:	learn: 0.0381304	total: 690ms	remaining: 766ms
# 474:	learn: 0.0380258	total: 692ms	remaining: 764ms
# 475:	learn: 0.0379449	total: 693ms	remaining: 763ms
# 476:	learn: 0.0378621	total: 694ms	remaining: 761ms
# 477:	learn: 0.0378035	total: 696ms	remaining: 760ms
# 478:	learn: 0.0377293	total: 697ms	remaining: 758ms
# 479:	learn: 0.0375357	total: 699ms	remaining: 757ms
# 480:	learn: 0.0374186	total: 700ms	remaining: 755ms
# 481:	learn: 0.0372413	total: 701ms	remaining: 754ms
# 482:	learn: 0.0370998	total: 703ms	remaining: 752ms
# 483:	learn: 0.0369894	total: 704ms	remaining: 750ms
# 484:	learn: 0.0368800	total: 705ms	remaining: 749ms
# 485:	learn: 0.0367120	total: 707ms	remaining: 747ms
# 486:	learn: 0.0365998	total: 708ms	remaining: 746ms
# 487:	learn: 0.0364963	total: 709ms	remaining: 744ms
# 488:	learn: 0.0364116	total: 710ms	remaining: 742ms
# 489:	learn: 0.0363000	total: 712ms	remaining: 741ms
# 490:	learn: 0.0362275	total: 713ms	remaining: 739ms
# 491:	learn: 0.0361394	total: 714ms	remaining: 738ms
# 492:	learn: 0.0360315	total: 716ms	remaining: 736ms
# 493:	learn: 0.0359260	total: 717ms	remaining: 734ms
# 494:	learn: 0.0358600	total: 718ms	remaining: 733ms
# 495:	learn: 0.0357371	total: 720ms	remaining: 731ms
# 496:	learn: 0.0356660	total: 721ms	remaining: 730ms
# 497:	learn: 0.0355694	total: 722ms	remaining: 728ms
# 498:	learn: 0.0354509	total: 723ms	remaining: 726ms
# 499:	learn: 0.0353556	total: 734ms	remaining: 734ms
# 500:	learn: 0.0352664	total: 737ms	remaining: 734ms
# 501:	learn: 0.0351600	total: 739ms	remaining: 733ms
# 502:	learn: 0.0350688	total: 740ms	remaining: 731ms
# 503:	learn: 0.0349880	total: 741ms	remaining: 729ms
# 504:	learn: 0.0348384	total: 742ms	remaining: 728ms
# 505:	learn: 0.0347622	total: 744ms	remaining: 726ms
# 506:	learn: 0.0346472	total: 745ms	remaining: 724ms
# 507:	learn: 0.0345927	total: 746ms	remaining: 723ms
# 508:	learn: 0.0345342	total: 748ms	remaining: 721ms
# 509:	learn: 0.0344695	total: 749ms	remaining: 720ms
# 510:	learn: 0.0344071	total: 750ms	remaining: 718ms
# 511:	learn: 0.0343469	total: 752ms	remaining: 717ms
# 512:	learn: 0.0342503	total: 753ms	remaining: 715ms
# 513:	learn: 0.0341438	total: 754ms	remaining: 713ms
# 514:	learn: 0.0340125	total: 756ms	remaining: 712ms
# 515:	learn: 0.0338809	total: 757ms	remaining: 710ms
# 516:	learn: 0.0338073	total: 758ms	remaining: 708ms
# 517:	learn: 0.0336605	total: 760ms	remaining: 707ms
# 518:	learn: 0.0335765	total: 761ms	remaining: 705ms
# 519:	learn: 0.0335162	total: 762ms	remaining: 704ms
# 520:	learn: 0.0334051	total: 764ms	remaining: 702ms
# 521:	learn: 0.0333043	total: 765ms	remaining: 701ms
# 522:	learn: 0.0332003	total: 766ms	remaining: 699ms
# 523:	learn: 0.0331409	total: 768ms	remaining: 697ms
# 524:	learn: 0.0330887	total: 769ms	remaining: 696ms
# 525:	learn: 0.0330321	total: 770ms	remaining: 694ms
# 526:	learn: 0.0329567	total: 772ms	remaining: 693ms
# 527:	learn: 0.0328956	total: 773ms	remaining: 691ms
# 528:	learn: 0.0328583	total: 774ms	remaining: 689ms
# 529:	learn: 0.0327688	total: 776ms	remaining: 688ms
# 530:	learn: 0.0326305	total: 777ms	remaining: 686ms
# 531:	learn: 0.0325400	total: 779ms	remaining: 685ms
# 532:	learn: 0.0324601	total: 780ms	remaining: 683ms
# 533:	learn: 0.0323392	total: 781ms	remaining: 682ms
# 534:	learn: 0.0322870	total: 783ms	remaining: 680ms
# 535:	learn: 0.0321971	total: 784ms	remaining: 679ms
# 536:	learn: 0.0321034	total: 785ms	remaining: 677ms
# 537:	learn: 0.0320339	total: 787ms	remaining: 675ms
# 538:	learn: 0.0319831	total: 788ms	remaining: 674ms
# 539:	learn: 0.0318980	total: 789ms	remaining: 672ms
# 540:	learn: 0.0317676	total: 791ms	remaining: 671ms
# 541:	learn: 0.0316730	total: 792ms	remaining: 670ms
# 542:	learn: 0.0316182	total: 794ms	remaining: 668ms
# 543:	learn: 0.0315410	total: 795ms	remaining: 666ms
# 544:	learn: 0.0314663	total: 797ms	remaining: 665ms
# 545:	learn: 0.0313926	total: 798ms	remaining: 663ms
# 546:	learn: 0.0312856	total: 799ms	remaining: 662ms
# 547:	learn: 0.0312525	total: 801ms	remaining: 660ms
# 548:	learn: 0.0311838	total: 802ms	remaining: 659ms
# 549:	learn: 0.0311411	total: 803ms	remaining: 657ms
# 550:	learn: 0.0310896	total: 805ms	remaining: 656ms
# 551:	learn: 0.0309637	total: 806ms	remaining: 654ms
# 552:	learn: 0.0308488	total: 807ms	remaining: 652ms
# 553:	learn: 0.0307872	total: 809ms	remaining: 651ms
# 554:	learn: 0.0307363	total: 810ms	remaining: 649ms
# 555:	learn: 0.0306318	total: 811ms	remaining: 648ms
# 556:	learn: 0.0305030	total: 813ms	remaining: 646ms
# 557:	learn: 0.0304596	total: 814ms	remaining: 645ms
# 558:	learn: 0.0303850	total: 815ms	remaining: 643ms
# 559:	learn: 0.0303387	total: 817ms	remaining: 642ms
# 560:	learn: 0.0302376	total: 818ms	remaining: 640ms
# 561:	learn: 0.0301372	total: 819ms	remaining: 639ms
# 562:	learn: 0.0300388	total: 821ms	remaining: 637ms
# 563:	learn: 0.0299296	total: 822ms	remaining: 635ms
# 564:	learn: 0.0298377	total: 823ms	remaining: 634ms
# 565:	learn: 0.0297672	total: 824ms	remaining: 632ms
# 566:	learn: 0.0296505	total: 826ms	remaining: 631ms
# 567:	learn: 0.0295448	total: 827ms	remaining: 629ms
# 568:	learn: 0.0294414	total: 829ms	remaining: 628ms
# 569:	learn: 0.0293943	total: 830ms	remaining: 626ms
# 570:	learn: 0.0293100	total: 831ms	remaining: 625ms
# 571:	learn: 0.0292691	total: 833ms	remaining: 623ms
# 572:	learn: 0.0292036	total: 834ms	remaining: 622ms
# 573:	learn: 0.0291167	total: 836ms	remaining: 620ms
# 574:	learn: 0.0289983	total: 837ms	remaining: 619ms
# 575:	learn: 0.0289099	total: 838ms	remaining: 617ms
# 576:	learn: 0.0288688	total: 839ms	remaining: 615ms
# 577:	learn: 0.0288104	total: 841ms	remaining: 614ms
# 578:	learn: 0.0287357	total: 842ms	remaining: 612ms
# 579:	learn: 0.0286364	total: 844ms	remaining: 611ms
# 580:	learn: 0.0285411	total: 845ms	remaining: 610ms
# 581:	learn: 0.0284346	total: 847ms	remaining: 608ms
# 582:	learn: 0.0283283	total: 848ms	remaining: 606ms
# 583:	learn: 0.0282857	total: 849ms	remaining: 605ms
# 584:	learn: 0.0282276	total: 851ms	remaining: 603ms
# 585:	learn: 0.0281274	total: 852ms	remaining: 602ms
# 586:	learn: 0.0280311	total: 853ms	remaining: 600ms
# 587:	learn: 0.0279750	total: 855ms	remaining: 599ms
# 588:	learn: 0.0279369	total: 856ms	remaining: 597ms
# 589:	learn: 0.0278392	total: 857ms	remaining: 596ms
# 590:	learn: 0.0277615	total: 858ms	remaining: 594ms
# 591:	learn: 0.0276911	total: 860ms	remaining: 593ms
# 592:	learn: 0.0275822	total: 861ms	remaining: 591ms
# 593:	learn: 0.0274380	total: 862ms	remaining: 589ms
# 594:	learn: 0.0273129	total: 864ms	remaining: 588ms
# 595:	learn: 0.0272373	total: 865ms	remaining: 586ms
# 596:	learn: 0.0271583	total: 866ms	remaining: 585ms
# 597:	learn: 0.0270986	total: 868ms	remaining: 583ms
# 598:	learn: 0.0270303	total: 869ms	remaining: 582ms
# 599:	learn: 0.0269968	total: 870ms	remaining: 580ms
# 600:	learn: 0.0269601	total: 872ms	remaining: 579ms
# 601:	learn: 0.0268832	total: 873ms	remaining: 577ms
# 602:	learn: 0.0268421	total: 874ms	remaining: 575ms
# 603:	learn: 0.0267513	total: 875ms	remaining: 574ms
# 604:	learn: 0.0266702	total: 877ms	remaining: 572ms
# 605:	learn: 0.0266060	total: 878ms	remaining: 571ms
# 606:	learn: 0.0265297	total: 879ms	remaining: 569ms
# 607:	learn: 0.0264029	total: 881ms	remaining: 568ms
# 608:	learn: 0.0263305	total: 882ms	remaining: 566ms
# 609:	learn: 0.0262403	total: 883ms	remaining: 565ms
# 610:	learn: 0.0261570	total: 884ms	remaining: 563ms
# 611:	learn: 0.0260521	total: 886ms	remaining: 562ms
# 612:	learn: 0.0260345	total: 888ms	remaining: 560ms
# 613:	learn: 0.0259857	total: 889ms	remaining: 559ms
# 614:	learn: 0.0259304	total: 890ms	remaining: 557ms
# 615:	learn: 0.0258854	total: 891ms	remaining: 556ms
# 616:	learn: 0.0258269	total: 893ms	remaining: 554ms
# 617:	learn: 0.0257424	total: 894ms	remaining: 553ms
# 618:	learn: 0.0256556	total: 896ms	remaining: 551ms
# 619:	learn: 0.0255910	total: 897ms	remaining: 550ms
# 620:	learn: 0.0255301	total: 898ms	remaining: 548ms
# 621:	learn: 0.0254571	total: 900ms	remaining: 547ms
# 622:	learn: 0.0254251	total: 901ms	remaining: 545ms
# 623:	learn: 0.0253649	total: 902ms	remaining: 544ms
# 624:	learn: 0.0252831	total: 904ms	remaining: 542ms
# 625:	learn: 0.0252244	total: 905ms	remaining: 541ms
# 626:	learn: 0.0251582	total: 906ms	remaining: 539ms
# 627:	learn: 0.0250850	total: 908ms	remaining: 538ms
# 628:	learn: 0.0250349	total: 909ms	remaining: 536ms
# 629:	learn: 0.0249370	total: 910ms	remaining: 535ms
# 630:	learn: 0.0248929	total: 911ms	remaining: 533ms
# 631:	learn: 0.0248257	total: 915ms	remaining: 533ms
# 632:	learn: 0.0247656	total: 917ms	remaining: 532ms
# 633:	learn: 0.0247004	total: 919ms	remaining: 530ms
# 634:	learn: 0.0246228	total: 922ms	remaining: 530ms
# 635:	learn: 0.0245485	total: 923ms	remaining: 528ms
# 636:	learn: 0.0244799	total: 925ms	remaining: 527ms
# 637:	learn: 0.0243913	total: 926ms	remaining: 525ms
# 638:	learn: 0.0243497	total: 927ms	remaining: 524ms
# 639:	learn: 0.0242733	total: 929ms	remaining: 522ms
# 640:	learn: 0.0242035	total: 930ms	remaining: 521ms
# 641:	learn: 0.0241451	total: 931ms	remaining: 519ms
# 642:	learn: 0.0240970	total: 933ms	remaining: 518ms
# 643:	learn: 0.0240287	total: 934ms	remaining: 516ms
# 644:	learn: 0.0239333	total: 935ms	remaining: 515ms
# 645:	learn: 0.0238903	total: 937ms	remaining: 513ms
# 646:	learn: 0.0238229	total: 938ms	remaining: 512ms
# 647:	learn: 0.0237918	total: 940ms	remaining: 510ms
# 648:	learn: 0.0237515	total: 941ms	remaining: 509ms
# 649:	learn: 0.0236944	total: 942ms	remaining: 507ms
# 650:	learn: 0.0236413	total: 944ms	remaining: 506ms
# 651:	learn: 0.0235969	total: 945ms	remaining: 505ms
# 652:	learn: 0.0235644	total: 947ms	remaining: 503ms
# 653:	learn: 0.0235025	total: 948ms	remaining: 502ms
# 654:	learn: 0.0234293	total: 949ms	remaining: 500ms
# 655:	learn: 0.0233437	total: 951ms	remaining: 499ms
# 656:	learn: 0.0232917	total: 952ms	remaining: 497ms
# 657:	learn: 0.0232467	total: 953ms	remaining: 496ms
# 658:	learn: 0.0232017	total: 955ms	remaining: 494ms
# 659:	learn: 0.0231220	total: 956ms	remaining: 492ms
# 660:	learn: 0.0230787	total: 957ms	remaining: 491ms
# 661:	learn: 0.0230293	total: 959ms	remaining: 489ms
# 662:	learn: 0.0229851	total: 960ms	remaining: 488ms
# 663:	learn: 0.0229482	total: 964ms	remaining: 488ms
# 664:	learn: 0.0229082	total: 965ms	remaining: 486ms
# 665:	learn: 0.0228729	total: 972ms	remaining: 487ms
# 666:	learn: 0.0228236	total: 974ms	remaining: 486ms
# 667:	learn: 0.0227455	total: 975ms	remaining: 484ms
# 668:	learn: 0.0226813	total: 977ms	remaining: 483ms
# 669:	learn: 0.0226174	total: 979ms	remaining: 482ms
# 670:	learn: 0.0225424	total: 981ms	remaining: 481ms
# 671:	learn: 0.0225019	total: 984ms	remaining: 480ms
# 672:	learn: 0.0224639	total: 988ms	remaining: 480ms
# 673:	learn: 0.0224410	total: 990ms	remaining: 479ms
# 674:	learn: 0.0224076	total: 991ms	remaining: 477ms
# 675:	learn: 0.0223520	total: 993ms	remaining: 476ms
# 676:	learn: 0.0223088	total: 994ms	remaining: 474ms
# 677:	learn: 0.0222388	total: 995ms	remaining: 473ms
# 678:	learn: 0.0221947	total: 996ms	remaining: 471ms
# 679:	learn: 0.0221332	total: 998ms	remaining: 469ms
# 680:	learn: 0.0220979	total: 999ms	remaining: 468ms
# 681:	learn: 0.0220518	total: 1s	remaining: 466ms
# 682:	learn: 0.0220077	total: 1s	remaining: 465ms
# 683:	learn: 0.0219389	total: 1s	remaining: 463ms
# 684:	learn: 0.0218852	total: 1s	remaining: 461ms
# 685:	learn: 0.0218425	total: 1s	remaining: 460ms
# 686:	learn: 0.0217903	total: 1.01s	remaining: 458ms
# 687:	learn: 0.0217511	total: 1.01s	remaining: 457ms
# 688:	learn: 0.0216865	total: 1.01s	remaining: 455ms
# 689:	learn: 0.0216404	total: 1.01s	remaining: 454ms
# 690:	learn: 0.0216129	total: 1.01s	remaining: 452ms
# 691:	learn: 0.0215418	total: 1.01s	remaining: 450ms
# 692:	learn: 0.0214899	total: 1.01s	remaining: 449ms
# 693:	learn: 0.0214322	total: 1.01s	remaining: 447ms
# 694:	learn: 0.0213776	total: 1.02s	remaining: 446ms
# 695:	learn: 0.0213420	total: 1.02s	remaining: 445ms
# 696:	learn: 0.0212620	total: 1.02s	remaining: 444ms
# 697:	learn: 0.0212268	total: 1.02s	remaining: 443ms
# 698:	learn: 0.0211671	total: 1.02s	remaining: 441ms
# 699:	learn: 0.0211164	total: 1.03s	remaining: 440ms
# 700:	learn: 0.0210545	total: 1.03s	remaining: 439ms
# 701:	learn: 0.0209928	total: 1.03s	remaining: 438ms
# 702:	learn: 0.0209297	total: 1.03s	remaining: 437ms
# 703:	learn: 0.0208838	total: 1.03s	remaining: 435ms
# 704:	learn: 0.0208062	total: 1.04s	remaining: 434ms
# 705:	learn: 0.0207479	total: 1.04s	remaining: 432ms
# 706:	learn: 0.0206919	total: 1.04s	remaining: 431ms
# 707:	learn: 0.0206630	total: 1.04s	remaining: 429ms
# 708:	learn: 0.0206377	total: 1.04s	remaining: 428ms
# 709:	learn: 0.0205673	total: 1.04s	remaining: 426ms
# 710:	learn: 0.0205212	total: 1.04s	remaining: 424ms
# 711:	learn: 0.0204516	total: 1.05s	remaining: 423ms
# 712:	learn: 0.0203892	total: 1.05s	remaining: 422ms
# 713:	learn: 0.0203626	total: 1.05s	remaining: 420ms
# 714:	learn: 0.0202996	total: 1.05s	remaining: 419ms
# 715:	learn: 0.0202401	total: 1.05s	remaining: 418ms
# 716:	learn: 0.0201878	total: 1.05s	remaining: 417ms
# 717:	learn: 0.0201672	total: 1.06s	remaining: 416ms
# 718:	learn: 0.0201127	total: 1.06s	remaining: 415ms
# 719:	learn: 0.0200600	total: 1.06s	remaining: 413ms
# 720:	learn: 0.0200302	total: 1.06s	remaining: 412ms
# 721:	learn: 0.0199693	total: 1.06s	remaining: 410ms
# 722:	learn: 0.0199095	total: 1.07s	remaining: 409ms
# 723:	learn: 0.0198739	total: 1.07s	remaining: 408ms
# 724:	learn: 0.0198262	total: 1.07s	remaining: 406ms
# 725:	learn: 0.0197720	total: 1.07s	remaining: 405ms
# 726:	learn: 0.0197253	total: 1.07s	remaining: 403ms
# 727:	learn: 0.0196913	total: 1.07s	remaining: 402ms
# 728:	learn: 0.0196443	total: 1.08s	remaining: 400ms
# 729:	learn: 0.0195802	total: 1.08s	remaining: 399ms
# 730:	learn: 0.0195546	total: 1.08s	remaining: 397ms
# 731:	learn: 0.0194862	total: 1.08s	remaining: 396ms
# 732:	learn: 0.0194331	total: 1.08s	remaining: 395ms
# 733:	learn: 0.0193719	total: 1.08s	remaining: 393ms
# 734:	learn: 0.0193469	total: 1.09s	remaining: 394ms
# 735:	learn: 0.0193165	total: 1.09s	remaining: 392ms
# 736:	learn: 0.0192532	total: 1.1s	remaining: 392ms
# 737:	learn: 0.0192276	total: 1.1s	remaining: 391ms
# 738:	learn: 0.0191774	total: 1.1s	remaining: 390ms
# 739:	learn: 0.0191345	total: 1.1s	remaining: 388ms
# 740:	learn: 0.0190785	total: 1.11s	remaining: 387ms
# 741:	learn: 0.0190139	total: 1.11s	remaining: 385ms
# 742:	learn: 0.0189741	total: 1.11s	remaining: 384ms
# 743:	learn: 0.0189397	total: 1.11s	remaining: 382ms
# 744:	learn: 0.0189016	total: 1.11s	remaining: 381ms
# 745:	learn: 0.0188512	total: 1.11s	remaining: 379ms
# 746:	learn: 0.0188078	total: 1.11s	remaining: 378ms
# 747:	learn: 0.0187564	total: 1.12s	remaining: 376ms
# 748:	learn: 0.0187026	total: 1.12s	remaining: 375ms
# 749:	learn: 0.0186689	total: 1.12s	remaining: 373ms
# 750:	learn: 0.0186397	total: 1.12s	remaining: 372ms
# 751:	learn: 0.0185821	total: 1.12s	remaining: 370ms
# 752:	learn: 0.0185341	total: 1.12s	remaining: 369ms
# 753:	learn: 0.0184879	total: 1.12s	remaining: 367ms
# 754:	learn: 0.0184426	total: 1.13s	remaining: 365ms
# 755:	learn: 0.0183857	total: 1.13s	remaining: 364ms
# 756:	learn: 0.0183277	total: 1.13s	remaining: 362ms
# 757:	learn: 0.0182974	total: 1.13s	remaining: 361ms
# 758:	learn: 0.0182544	total: 1.13s	remaining: 359ms
# 759:	learn: 0.0182301	total: 1.13s	remaining: 358ms
# 760:	learn: 0.0181788	total: 1.13s	remaining: 356ms
# 761:	learn: 0.0181393	total: 1.14s	remaining: 355ms
# 762:	learn: 0.0181087	total: 1.14s	remaining: 353ms
# 763:	learn: 0.0180583	total: 1.14s	remaining: 352ms
# 764:	learn: 0.0180219	total: 1.14s	remaining: 350ms
# 765:	learn: 0.0179637	total: 1.14s	remaining: 349ms
# 766:	learn: 0.0179362	total: 1.14s	remaining: 347ms
# 767:	learn: 0.0179129	total: 1.14s	remaining: 346ms
# 768:	learn: 0.0178610	total: 1.15s	remaining: 344ms
# 769:	learn: 0.0178307	total: 1.15s	remaining: 343ms
# 770:	learn: 0.0177993	total: 1.15s	remaining: 341ms
# 771:	learn: 0.0177504	total: 1.15s	remaining: 340ms
# 772:	learn: 0.0177193	total: 1.15s	remaining: 338ms
# 773:	learn: 0.0177032	total: 1.15s	remaining: 336ms
# 774:	learn: 0.0176579	total: 1.15s	remaining: 335ms
# 775:	learn: 0.0176269	total: 1.16s	remaining: 333ms
# 776:	learn: 0.0176031	total: 1.16s	remaining: 332ms
# 777:	learn: 0.0175431	total: 1.16s	remaining: 330ms
# 778:	learn: 0.0175169	total: 1.16s	remaining: 329ms
# 779:	learn: 0.0174724	total: 1.16s	remaining: 327ms
# 780:	learn: 0.0174277	total: 1.16s	remaining: 326ms
# 781:	learn: 0.0173897	total: 1.16s	remaining: 324ms
# 782:	learn: 0.0173446	total: 1.16s	remaining: 323ms
# 783:	learn: 0.0173215	total: 1.17s	remaining: 321ms
# 784:	learn: 0.0172739	total: 1.17s	remaining: 320ms
# 785:	learn: 0.0172177	total: 1.17s	remaining: 318ms
# 786:	learn: 0.0171850	total: 1.17s	remaining: 317ms
# 787:	learn: 0.0171491	total: 1.17s	remaining: 315ms
# 788:	learn: 0.0171030	total: 1.17s	remaining: 314ms
# 789:	learn: 0.0170478	total: 1.17s	remaining: 312ms
# 790:	learn: 0.0170137	total: 1.17s	remaining: 310ms
# 791:	learn: 0.0169833	total: 1.18s	remaining: 309ms
# 792:	learn: 0.0169531	total: 1.18s	remaining: 307ms
# 793:	learn: 0.0169007	total: 1.18s	remaining: 306ms
# 794:	learn: 0.0168477	total: 1.18s	remaining: 304ms
# 795:	learn: 0.0168026	total: 1.18s	remaining: 303ms
# 796:	learn: 0.0167700	total: 1.18s	remaining: 301ms
# 797:	learn: 0.0167503	total: 1.18s	remaining: 300ms
# 798:	learn: 0.0167344	total: 1.19s	remaining: 298ms
# 799:	learn: 0.0166967	total: 1.19s	remaining: 297ms
# 800:	learn: 0.0166776	total: 1.19s	remaining: 295ms
# 801:	learn: 0.0166509	total: 1.19s	remaining: 294ms
# 802:	learn: 0.0166095	total: 1.19s	remaining: 292ms
# 803:	learn: 0.0165545	total: 1.19s	remaining: 291ms
# 804:	learn: 0.0165265	total: 1.19s	remaining: 289ms
# 805:	learn: 0.0164866	total: 1.2s	remaining: 288ms
# 806:	learn: 0.0164453	total: 1.2s	remaining: 286ms
# 807:	learn: 0.0164126	total: 1.2s	remaining: 285ms
# 808:	learn: 0.0163887	total: 1.2s	remaining: 283ms
# 809:	learn: 0.0163599	total: 1.2s	remaining: 282ms
# 810:	learn: 0.0163405	total: 1.2s	remaining: 280ms
# 811:	learn: 0.0163000	total: 1.2s	remaining: 279ms
# 812:	learn: 0.0162651	total: 1.21s	remaining: 277ms
# 813:	learn: 0.0162423	total: 1.21s	remaining: 276ms
# 814:	learn: 0.0161935	total: 1.21s	remaining: 274ms
# 815:	learn: 0.0161476	total: 1.21s	remaining: 273ms
# 816:	learn: 0.0161212	total: 1.21s	remaining: 271ms
# 817:	learn: 0.0160783	total: 1.21s	remaining: 270ms
# 818:	learn: 0.0160276	total: 1.21s	remaining: 268ms
# 819:	learn: 0.0159854	total: 1.21s	remaining: 267ms
# 820:	learn: 0.0159607	total: 1.22s	remaining: 265ms
# 821:	learn: 0.0159314	total: 1.22s	remaining: 264ms
# 822:	learn: 0.0158838	total: 1.22s	remaining: 262ms
# 823:	learn: 0.0158383	total: 1.22s	remaining: 261ms
# 824:	learn: 0.0157988	total: 1.22s	remaining: 259ms
# 825:	learn: 0.0157724	total: 1.22s	remaining: 258ms
# 826:	learn: 0.0157527	total: 1.22s	remaining: 256ms
# 827:	learn: 0.0157368	total: 1.23s	remaining: 255ms
# 828:	learn: 0.0157106	total: 1.23s	remaining: 253ms
# 829:	learn: 0.0156817	total: 1.23s	remaining: 252ms
# 830:	learn: 0.0156506	total: 1.23s	remaining: 250ms
# 831:	learn: 0.0156046	total: 1.23s	remaining: 249ms
# 832:	learn: 0.0155680	total: 1.23s	remaining: 247ms
# 833:	learn: 0.0155216	total: 1.23s	remaining: 246ms
# 834:	learn: 0.0154894	total: 1.23s	remaining: 244ms
# 835:	learn: 0.0154426	total: 1.24s	remaining: 243ms
# 836:	learn: 0.0154171	total: 1.24s	remaining: 241ms
# 837:	learn: 0.0153972	total: 1.24s	remaining: 240ms
# 838:	learn: 0.0153633	total: 1.24s	remaining: 238ms
# 839:	learn: 0.0153280	total: 1.24s	remaining: 237ms
# 840:	learn: 0.0152942	total: 1.24s	remaining: 235ms
# 841:	learn: 0.0152646	total: 1.24s	remaining: 234ms
# 842:	learn: 0.0152350	total: 1.25s	remaining: 232ms
# 843:	learn: 0.0151996	total: 1.25s	remaining: 231ms
# 844:	learn: 0.0151658	total: 1.25s	remaining: 229ms
# 845:	learn: 0.0151381	total: 1.25s	remaining: 228ms
# 846:	learn: 0.0151003	total: 1.25s	remaining: 226ms
# 847:	learn: 0.0150830	total: 1.25s	remaining: 224ms
# 848:	learn: 0.0150489	total: 1.25s	remaining: 223ms
# 849:	learn: 0.0150067	total: 1.25s	remaining: 221ms
# 850:	learn: 0.0149622	total: 1.26s	remaining: 220ms
# 851:	learn: 0.0149353	total: 1.26s	remaining: 218ms
# 852:	learn: 0.0148939	total: 1.26s	remaining: 217ms
# 853:	learn: 0.0148543	total: 1.26s	remaining: 215ms
# 854:	learn: 0.0148398	total: 1.26s	remaining: 214ms
# 855:	learn: 0.0148183	total: 1.26s	remaining: 213ms
# 856:	learn: 0.0147910	total: 1.26s	remaining: 211ms
# 857:	learn: 0.0147583	total: 1.27s	remaining: 210ms
# 858:	learn: 0.0147200	total: 1.27s	remaining: 208ms
# 859:	learn: 0.0146909	total: 1.27s	remaining: 207ms
# 860:	learn: 0.0146686	total: 1.27s	remaining: 205ms
# 861:	learn: 0.0146489	total: 1.27s	remaining: 204ms
# 862:	learn: 0.0146083	total: 1.27s	remaining: 202ms
# 863:	learn: 0.0145842	total: 1.27s	remaining: 201ms
# 864:	learn: 0.0145558	total: 1.28s	remaining: 199ms
# 865:	learn: 0.0145256	total: 1.28s	remaining: 198ms
# 866:	learn: 0.0144922	total: 1.28s	remaining: 197ms
# 867:	learn: 0.0144672	total: 1.28s	remaining: 195ms
# 868:	learn: 0.0144437	total: 1.28s	remaining: 194ms
# 869:	learn: 0.0144092	total: 1.29s	remaining: 192ms
# 870:	learn: 0.0143833	total: 1.29s	remaining: 191ms
# 871:	learn: 0.0143512	total: 1.29s	remaining: 189ms
# 872:	learn: 0.0143210	total: 1.29s	remaining: 188ms
# 873:	learn: 0.0142852	total: 1.29s	remaining: 186ms
# 874:	learn: 0.0142531	total: 1.29s	remaining: 185ms
# 875:	learn: 0.0142334	total: 1.29s	remaining: 183ms
# 876:	learn: 0.0142166	total: 1.29s	remaining: 182ms
# 877:	learn: 0.0142029	total: 1.3s	remaining: 180ms
# 878:	learn: 0.0141768	total: 1.3s	remaining: 179ms
# 879:	learn: 0.0141526	total: 1.3s	remaining: 177ms
# 880:	learn: 0.0141252	total: 1.3s	remaining: 176ms
# 881:	learn: 0.0140863	total: 1.3s	remaining: 174ms
# 882:	learn: 0.0140532	total: 1.3s	remaining: 173ms
# 883:	learn: 0.0140312	total: 1.3s	remaining: 171ms
# 884:	learn: 0.0140059	total: 1.31s	remaining: 170ms
# 885:	learn: 0.0139736	total: 1.31s	remaining: 168ms
# 886:	learn: 0.0139343	total: 1.31s	remaining: 167ms
# 887:	learn: 0.0139128	total: 1.31s	remaining: 165ms
# 888:	learn: 0.0138877	total: 1.31s	remaining: 164ms
# 889:	learn: 0.0138620	total: 1.31s	remaining: 162ms
# 890:	learn: 0.0138291	total: 1.31s	remaining: 161ms
# 891:	learn: 0.0138049	total: 1.31s	remaining: 159ms
# 892:	learn: 0.0137680	total: 1.32s	remaining: 158ms
# 893:	learn: 0.0137396	total: 1.32s	remaining: 157ms
# 894:	learn: 0.0137196	total: 1.32s	remaining: 155ms
# 895:	learn: 0.0136955	total: 1.32s	remaining: 154ms
# 896:	learn: 0.0136765	total: 1.33s	remaining: 152ms
# 897:	learn: 0.0136580	total: 1.33s	remaining: 151ms
# 898:	learn: 0.0136331	total: 1.33s	remaining: 150ms
# 899:	learn: 0.0135970	total: 1.34s	remaining: 149ms
# 900:	learn: 0.0135666	total: 1.34s	remaining: 147ms
# 901:	learn: 0.0135408	total: 1.34s	remaining: 146ms
# 902:	learn: 0.0135054	total: 1.34s	remaining: 144ms
# 903:	learn: 0.0134702	total: 1.34s	remaining: 143ms
# 904:	learn: 0.0134463	total: 1.35s	remaining: 141ms
# 905:	learn: 0.0134225	total: 1.35s	remaining: 140ms
# 906:	learn: 0.0133998	total: 1.35s	remaining: 139ms
# 907:	learn: 0.0133690	total: 1.35s	remaining: 137ms
# 908:	learn: 0.0133506	total: 1.35s	remaining: 136ms
# 909:	learn: 0.0133243	total: 1.35s	remaining: 134ms
# 910:	learn: 0.0132879	total: 1.36s	remaining: 133ms
# 911:	learn: 0.0132599	total: 1.36s	remaining: 131ms
# 912:	learn: 0.0132331	total: 1.36s	remaining: 130ms
# 913:	learn: 0.0132025	total: 1.36s	remaining: 128ms
# 914:	learn: 0.0131825	total: 1.36s	remaining: 127ms
# 915:	learn: 0.0131487	total: 1.36s	remaining: 125ms
# 916:	learn: 0.0131277	total: 1.36s	remaining: 124ms
# 917:	learn: 0.0130936	total: 1.37s	remaining: 122ms
# 918:	learn: 0.0130713	total: 1.37s	remaining: 121ms
# 919:	learn: 0.0130493	total: 1.37s	remaining: 119ms
# 920:	learn: 0.0130302	total: 1.37s	remaining: 118ms
# 921:	learn: 0.0129953	total: 1.37s	remaining: 116ms
# 922:	learn: 0.0129722	total: 1.37s	remaining: 115ms
# 923:	learn: 0.0129477	total: 1.37s	remaining: 113ms
# 924:	learn: 0.0129279	total: 1.38s	remaining: 112ms
# 925:	learn: 0.0129119	total: 1.38s	remaining: 110ms
# 926:	learn: 0.0128923	total: 1.38s	remaining: 109ms
# 927:	learn: 0.0128669	total: 1.38s	remaining: 107ms
# 928:	learn: 0.0128410	total: 1.38s	remaining: 106ms
# 929:	learn: 0.0128219	total: 1.38s	remaining: 104ms
# 930:	learn: 0.0127954	total: 1.38s	remaining: 103ms
# 931:	learn: 0.0127715	total: 1.38s	remaining: 101ms
# 932:	learn: 0.0127582	total: 1.39s	remaining: 99.5ms
# 933:	learn: 0.0127370	total: 1.39s	remaining: 98ms
# 934:	learn: 0.0127100	total: 1.39s	remaining: 96.5ms
# 935:	learn: 0.0126928	total: 1.39s	remaining: 95ms
# 936:	learn: 0.0126654	total: 1.39s	remaining: 93.5ms
# 937:	learn: 0.0126355	total: 1.39s	remaining: 92.1ms
# 938:	learn: 0.0126202	total: 1.39s	remaining: 90.6ms
# 939:	learn: 0.0126000	total: 1.4s	remaining: 89.1ms
# 940:	learn: 0.0125743	total: 1.4s	remaining: 87.6ms
# 941:	learn: 0.0125509	total: 1.4s	remaining: 86.1ms
# 942:	learn: 0.0125394	total: 1.4s	remaining: 84.6ms
# 943:	learn: 0.0125062	total: 1.4s	remaining: 83.1ms
# 944:	learn: 0.0124830	total: 1.4s	remaining: 81.6ms
# 945:	learn: 0.0124525	total: 1.4s	remaining: 80.1ms
# 946:	learn: 0.0124215	total: 1.4s	remaining: 78.6ms
# 947:	learn: 0.0124056	total: 1.41s	remaining: 77.1ms
# 948:	learn: 0.0123846	total: 1.41s	remaining: 75.6ms
# 949:	learn: 0.0123528	total: 1.41s	remaining: 74.1ms
# 950:	learn: 0.0123301	total: 1.41s	remaining: 72.6ms
# 951:	learn: 0.0123103	total: 1.41s	remaining: 71.1ms
# 952:	learn: 0.0122907	total: 1.41s	remaining: 69.6ms
# 953:	learn: 0.0122797	total: 1.41s	remaining: 68.2ms
# 954:	learn: 0.0122558	total: 1.41s	remaining: 66.7ms
# 955:	learn: 0.0122452	total: 1.42s	remaining: 65.2ms
# 956:	learn: 0.0122210	total: 1.42s	remaining: 63.7ms
# 957:	learn: 0.0121961	total: 1.42s	remaining: 62.2ms
# 958:	learn: 0.0121657	total: 1.42s	remaining: 60.7ms
# 959:	learn: 0.0121458	total: 1.42s	remaining: 59.2ms
# 960:	learn: 0.0121208	total: 1.42s	remaining: 57.7ms
# 961:	learn: 0.0121009	total: 1.42s	remaining: 56.3ms
# 962:	learn: 0.0120818	total: 1.43s	remaining: 54.8ms
# 963:	learn: 0.0120720	total: 1.43s	remaining: 53.3ms
# 964:	learn: 0.0120507	total: 1.43s	remaining: 51.8ms
# 965:	learn: 0.0120218	total: 1.43s	remaining: 50.3ms
# 966:	learn: 0.0119989	total: 1.43s	remaining: 48.8ms
# 967:	learn: 0.0119781	total: 1.43s	remaining: 47.3ms
# 968:	learn: 0.0119593	total: 1.43s	remaining: 45.9ms
# 969:	learn: 0.0119347	total: 1.43s	remaining: 44.4ms
# 970:	learn: 0.0119144	total: 1.44s	remaining: 42.9ms
# 971:	learn: 0.0118958	total: 1.44s	remaining: 41.4ms
# 972:	learn: 0.0118798	total: 1.44s	remaining: 39.9ms
# 973:	learn: 0.0118609	total: 1.44s	remaining: 38.5ms
# 974:	learn: 0.0118463	total: 1.44s	remaining: 37ms
# 975:	learn: 0.0118278	total: 1.44s	remaining: 35.5ms
# 976:	learn: 0.0117994	total: 1.44s	remaining: 34ms
# 977:	learn: 0.0117782	total: 1.45s	remaining: 32.5ms
# 978:	learn: 0.0117601	total: 1.45s	remaining: 31ms
# 979:	learn: 0.0117542	total: 1.45s	remaining: 29.6ms
# 980:	learn: 0.0117299	total: 1.45s	remaining: 28.1ms
# 981:	learn: 0.0117070	total: 1.45s	remaining: 26.6ms
# 982:	learn: 0.0116916	total: 1.45s	remaining: 25.1ms
# 983:	learn: 0.0116829	total: 1.45s	remaining: 23.6ms
# 984:	learn: 0.0116615	total: 1.46s	remaining: 22.2ms
# 985:	learn: 0.0116513	total: 1.46s	remaining: 20.7ms
# 986:	learn: 0.0116303	total: 1.46s	remaining: 19.2ms
# 987:	learn: 0.0116029	total: 1.46s	remaining: 17.8ms
# 988:	learn: 0.0115887	total: 1.46s	remaining: 16.3ms
# 989:	learn: 0.0115713	total: 1.47s	remaining: 14.8ms
# 990:	learn: 0.0115522	total: 1.47s	remaining: 13.3ms
# 991:	learn: 0.0115387	total: 1.47s	remaining: 11.9ms
# 992:	learn: 0.0115242	total: 1.47s	remaining: 10.4ms
# 993:	learn: 0.0115078	total: 1.47s	remaining: 8.89ms
# 994:	learn: 0.0114911	total: 1.47s	remaining: 7.41ms
# 995:	learn: 0.0114742	total: 1.48s	remaining: 5.92ms
# 996:	learn: 0.0114507	total: 1.48s	remaining: 4.44ms
# 997:	learn: 0.0114341	total: 1.48s	remaining: 2.96ms
# 998:	learn: 0.0114140	total: 1.48s	remaining: 1.48ms
# 999:	learn: 0.0113916	total: 1.48s	remaining: 0us
# * GradientBoostingClassifier

# %%
df_models.sort_values(by = 'roc_auc', ascending = False).head()
# Out:
#                         model  roc_auc  precision  recall
# 0               XGBClassifier    0.903      0.726   0.910
# 1          CatBoostClassifier    0.892      0.685   0.910
# 2  GradientBoostingClassifier    0.890      0.728   0.881

# %% [markdown]
# A for-profit organization is likely to be forced to use its marketing budget as judiciously as possible: Profitability is key. As a result, precision and the ROC-AUC score are most important.  As a result, XGBClassifier therefore is probably a better choice as it provides a better ROC-AUC score than GradientBoostingClassifier. While GradientBoostingClassifier has a better precision score than that of XGBClassifier, the difference is minimal.

# %% [markdown]
# **Examine the performance of the best model**

# %% [markdown]
# Finally, we can take our best model - the XGBClassifier - and fit the data on this. To do this step, we will first define our selected model, then we will pass its configuration to get_pipeline( ) with our training data. Then, we will fit( ) the training data and use predict( ) to return our predictions from the newly trained model.

# %%
selected_model = XGBClassifier(random_state = 42)
bundled_pipeline = get_pipeline(X_train, selected_model)
bundled_pipeline.fit(X_train, y_train)
y_pred = bundled_pipeline.predict(X_test)
